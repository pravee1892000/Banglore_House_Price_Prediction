# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset

# %%
# Load the dataset
df = pd.read_csv('bangalore_house_data.csv')

# %% [markdown]
# # shape

# %%
data.shape
# Out:
# (7000, 12)

# %% [markdown]
# # display

# %%
data.head()
# Out:
#       Location  Area (sqft)  Bedrooms  Bathrooms  Parking Spaces  \
# 0       Hebbal         2286         3          2               3
# 1  Indiranagar         3029         2          2               0
# 2  Malleswaram         3335         3          2               3
# 3   HSR Layout         2424         3          2               2
# 4   Whitefield         3632         2          2               2
#
#    Age of Property (years)  Floor  Total Floors       Furnishing  \
# 0                       12      1             4   Semi-Furnished
# 1                       29      3            10      Unfurnished
# 2                        1      2             6   Semi-Furnished
# 3                        9      1             3  Fully-Furnished
# 4                       15      1             3      Unfurnished
#
#        Property Type Nearby Metro (Y/N)  Price (Lakhs)
# 0  Independent House                  N          97.97
# 1          Apartment                  N         232.44
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Location                 7000 non-null   object
#  1   Area (sqft)              7000 non-null   int64
#  2   Bedrooms                 7000 non-null   int64
#  3   Bathrooms                7000 non-null   int64
#  4   Parking Spaces           7000 non-null   int64
#  5   Age of Property (years)  7000 non-null   int64
#  6   Floor                    7000 non-null   int64
#  7   Total Floors             7000 non-null   int64
#  8   Furnishing               7000 non-null   object
#  9   Property Type            7000 non-null   object
#  10  Nearby Metro (Y/N)       7000 non-null   object
#  11  Price (Lakhs)            7000 non-null   float64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 656.4+ KB

# %%
data.isnull().sum()
# Out:
# Location                   0
# Area (sqft)                0
# Bedrooms                   0
# Bathrooms                  0
# Parking Spaces             0
# Age of Property (years)    0
# Floor                      0
# Total Floors               0
# Furnishing                 0
# Property Type              0
# Nearby Metro (Y/N)         0
# Price (Lakhs)              0
# dtype: int64

# %%
data.describe()
# Out:
#        Area (sqft)     Bedrooms    Bathrooms  Parking Spaces  \
# count  7000.000000  7000.000000  7000.000000     7000.000000
# mean   2774.336000     2.990143     3.000143        1.511143
# std    1264.477446     1.425199     1.405549        1.118697
# min     600.000000     1.000000     1.000000        0.000000
# 25%    1673.000000     2.000000     2.000000        1.000000
# 50%    2759.000000     3.000000     3.000000        2.000000
# 75%    3860.000000     4.000000     4.000000        3.000000
# max    5000.000000     5.000000     5.000000        3.000000
#
#        Age of Property (years)        Floor  Total Floors  Price (Lakhs)
# count              7000.000000  7000.000000   7000.000000    7000.000000
# mean                 15.023714     3.227286      5.525714     175.636446
# std                   8.975448     2.308144      2.889481      90.796098
# min                   0.000000     1.000000      1.000000      24.620000
# ...

# %% [markdown]
# # NumPy statistics

# %%
prices = data['Price (Lakhs)'].values
print(f"Mean Price: {np.mean(prices)}")
print(f"Median Price: {np.median(prices)}")
print(f"Price Standard Deviation: {np.std(prices)}")
# Out:
# Mean Price: 175.63644571428574
# Median Price: 165.995
# Price Standard Deviation: 90.78961205617033

# %% [markdown]
# # Price (Lakh) vs Number of Houses

# %%
plt.figure(figsize=(10,6))
sns.histplot(data['Price (Lakhs)'], bins=50, kde=True)
plt.title('Price Distribution')
plt.xlabel('Price (Lakh)')
plt.ylabel('Number of Houses')
plt.show()

# %% [markdown]
# # Bedroom counts

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Bedrooms', data=data)
plt.title('Bedroom Distribution')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Price vs Area sqft

# %%
plt.figure(figsize=(10,6))
plt.scatter(data['Area (sqft)'], data['Price (Lakhs)'])
plt.title('Price vs Total Square Feet')
plt.xlabel('Total Square Feet')
plt.ylabel('Price (Lakh)')
plt.show()
